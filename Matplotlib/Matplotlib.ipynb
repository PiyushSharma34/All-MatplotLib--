# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=[20,30,40,50]
y=[2,20,30,40]

plt.plot(x,y)
plt.show()

# %%
x=[20,30,40,50]
y=[2,20,30,40]


a=[15,23,22,55]
b=[2,20,30,40]

plt.title('This is Line Plot',color="y",style='italic',fontsize=20,loc='left')
plt.plot(x,y,color='red',marker="s")
plt.plot(a,b,marker="*")
plt.grid(color="r",ls=":",lw=1.8)
plt.show()

# %%
x=[20,30,40,50]
y=[2,20,30,40]

plt.plot(x,y,color='red',marker="*")

plt.show()

# %%
x=[20,30,40,50]
y=[2,20,30,40]

plt.plot(x,y,color='red',marker="*",mec="black",ms="30")
plt.show()

# %%
# '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted';


x=[20,30,40,50]

y=[2,20,30,40]

plt.plot(x,y,color='red',marker="*",mec="black",ms="10",ls="--")

plt.show()

# %%
x=[20,30,40,50]

y=["css","Java","Html","jquery"]

plt.plot(y,x,color='red',marker="*",mec="black",ms="10",ls="--")

plt.title("Hello Piyush")

plt.grid()

# %%
plt.plot(x,y,"r*--")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Hello Piyush")

plt.show()

# %%
plt.plot(x,y,"b*:")
plt.legend(["Single Element"])

plt.savefig("One.png",dpi=200)
plt.show()

# %%
x=["Html","Java","Python","CSS"]
y=[45,78,65,54]
c=["y","r","b","g"]
plt.bar(x,y,width=0.4,color=c,align='edge')
plt.title("Bar Graph",fontsize=30,color="red")
plt.xlabel("Courses",fontsize=20,color="blue")
# plt.legend("Course Bar")
plt.ylabel("Number")
# plt.savefig("BarGraph.png",dpi=200)
plt.show()

# %%
x=["Html","Java","Python","CSS"]
y=[45,78,65,54]
c=["y","r","b","g"]

plt.bar(x,y,width=0.4,color=c,align='edge',edgecolor="y",linewidth=5,alpha=0.2)  



# width for bar width
# align= for lebel 
# edgecolor for bar border color
# linewidth for bar color px 
# alpha for bar blueness



plt.title("Bar Graph",fontsize=30,color="red")
plt.xlabel("Courses",fontsize=20,color="blue",loc="left")
plt.ylabel("Number")
plt.show()

# %%
x=["Html","Java","Python","CSS"]

y=[45,78,65,54]

c=["y","r","b","g"]

plt.barh(x,y,color=c,height=0.8)  



plt.title("Bar Graph",fontsize=30,color="red")

plt.ylabel("Courses",fontsize=20,color="blue")

plt.xlabel("Number")

plt.show()

# %%
import matplotlib.pyplot as plt

day=["piyush","Suneeta","raja","madhuree","Atul","Shivaneee"]
no=[7,12,15,19,22,30]
sizes=[400,600,700,300,200,150]
c=["r","k","c","b","y","g"]
plt.scatter(day,no,color=c,s=sizes)

plt.title("This is Scatter Plot",color="r",style="italic",fontsize=20)
plt.xlabel("Name",color="r",style="italic",fontsize=20)
plt.ylabel("Number",color="r",style="italic",fontsize=20)
plt.colorbar()
plt.show()

# %%
plt.plot(df["Name"],df["age"],marker="*",color="r",markersize=20,markeredgecolor="b")
plt.title("This is Line Chart")
plt.ylabel("Age",fontsize="20",color="c")
plt.xlabel("Name",fontsize="20",color="c")
plt.legend("Name")
plt.show()

# %%
a=np.array(["Allahabad","Patna","Kanpur","Deharadun"])

b=np.array([15,12,18,22])
c=("r","y","b","r")

plt.figure(figsize=(7,3))

plt.title("This is Bar Chart",fontsize=20,color="y")

plt.bar(a,b,color=c,ec="b",lw=2,width=0.5)

plt.show()

# %%
# color ==>>cmykrgbw --->cyan.magenta,yellow,black,red,green,blue,white

# %%
a=np.array(["Allahabad","Patna","Kanpur","Deharadun"])
b=np.array([15,12,18,22])
c=("r","y","b","r")

plt.figure(figsize=(7,3))
plt
plt.barh(a,b,color=c,edgecolor="b",alpha=0.2)
plt.show()

# %%
a=np.random.randint(130,190,40)
a
# Out:
# array([183, 139, 165, 135, 149, 179, 153, 132, 158, 149, 164, 145, 155,
#        131, 147, 138, 143, 164, 170, 134, 178, 131, 159, 152, 134, 165,
#        179, 189, 163, 176, 177, 143, 162, 189, 150, 174, 147, 185, 151,
#        154])

# %%
b=np.random.randint(130,190,40)
b
# Out:
# array([183, 151, 133, 154, 162, 148, 173, 158, 134, 186, 188, 152, 152,
#        157, 142, 133, 147, 178, 175, 145, 137, 175, 130, 152, 183, 135,
#        155, 187, 144, 145, 170, 145, 160, 161, 174, 135, 131, 136, 167,
#        134])

# %%
plt.scatter(a,b,color="g")
plt.colorbar()

plt.show()

# %%
plt.savefig("scatter.png",dpi=20)

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (10.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
b=np.array([15,12,18,22])
c=("r","y","b","r")

plt.figure(figsize=(7,3))
plt.title("This is Pie Chart",fontsize=20,color="y")

name = ["Apples", "Bananas", "Cherries", "Dates"]
c=["red","k","green","yellow"]
plt.pie(y, labels = name,shadow = True,colors=c)
plt.legend()
plt.figure(figsize=(7,6))

plt.show()

# %%
b=np.array([15,12,18,22])
c=("r","y","g","r")

plt.figure(figsize=(7,3))
plt.title("This is Pie Chart",fontsize=20,color="y")

name = ["Apples", "Bananas", "Cherries", "Dates"]
c=["red","k","green","yellow"]
s=[0,0.2,0,0]
plt.pie(y, labels = name,shadow = True,colors=c,explode=s)
# plt.legend()
plt.figure(figsize=(10,3))

plt.savefig("S.png")
# plt.show()

# %%
import pandas as pd
c=pd.read_csv("Country.csv")
c
# Out:
#    Year  India   Pak  China  USA
# 0  2000    200   522    450  487
# 1  2001    230   400    458  145
# 2  2002    250   300    654  488
# 3  2003    400  2500    484  458
# 4  2004    450   144    154  254
# 5  2005    500   222    125  145
# 6  2006    600   144    458  145
# 7  2007    400   255    566  455
# 8  2008    200   123    154  145

# %%
import matplotlib.pyplot as plt
plt.plot(c["Year"],c["India"],marker="*",ms="20",lw="0.2",mec="y")

plt.title("This is India Bar Chart",color="g" ,fontsize=20)
plt.show()

# %%
q=[0,20,40,60,80]
b=[10,20,30,4,5]

plt.hist(b)
plt.savefig("Ss.png")

# %%
b=np.array([15,12,18,22])
c=("r","y","g","b")

plt.title("This is Pie Chart",fontsize=20,color="y")

name = ["Apples", "Bananas", "Cherries", "Dates"]
c=["r","k","green","yellow"]
s=[0,0.2,0,0]


plt.pie(y, labels = name,colors=c,rotatelabels=True,explode=s,autopct="%0.2f%%",labeldistance=1.3)
plt.savefig("ww.png")

# %%
a=[4,5,6,7,8,9]
b=[7,6,9,8,7,4]
plt.stem(a,b,linefmt="-.",markerfmt="ro",basefmt="y",label="Pyton")
plt.legend()
plt.title("This is Stem Chart",fontsize=20,color="y")

plt.show()

# %%
a=[4,5,6,7,8,9]
b=[7,6,9,8,7,4]
plt.stem(a,b,linefmt="-.",markerfmt="r+",basefmt="y",bottom=9)
plt.show()

# %%
# this is stem plot 

a=[20,30,40,50,10]
plt.boxplot(a)
plt.grid()
plt.show()

# %%
a=[20,30,40,50,10]
plt.boxplot(a,vert=False,widths=0.3,labels=["Python"],patch_artist=True)
plt.title("This is BoxPlot",color="r",fontsize=30,alpha=0.4,style="italic")
# plt.legend("Python" ,loc=3)
# plt.savefig("Boxplot",dpi=200,facecolor="y",transparent=True)
plt.show()

# %%
a=[20,30,40,50,10]
plt.boxplot(a,vert=False,widths=0.3,labels=["Python"],showmeans=True,boxprops=dict(color="r"))
plt.title("This is BoxPlot",color="r",fontsize=30,alpha=0.4,style="italic")
plt.show()

# %%
x=[1,2,3,4,5]
q=[1,2,3,4,5]
w=[1,2,3,4,5]
e=[2,1,3,4,5]
l=["Area1","Area2","Area3"]
plt.stackplot(x,q,w,e,labels=l)
plt.legend(loc=2)
plt.show()

# %%
a=[10,20,30,40,50]
y=[20,30,40,50,60]
plt.step(a,y,marker="*",markeredgecolor="r",markersize=20,linestyle=":",label=["Python"])
plt.title("This is Step Chart",color="y",fontsize=20,style="italic")

plt.legend(loc=2)
plt.xlabel("Python",color="r",fontsize=20)
plt.ylabel("Number",color="r",fontsize=20)

# plt.grid()

plt.savefig("Step1",dpi=200,facecolor="r",transparent=True)
plt.show()

# %%
a=[41, 41, 63, 57, 66, 53, 58, 51, 47, 61, 64, 54, 41, 45, 44, 56, 50,
       45, 66, 62, 68, 61, 41, 55, 52, 52, 52, 43, 51, 68, 54, 52, 66, 45,
       51, 69, 52, 56, 63, 51, 67, 40, 47, 51, 56, 67, 46, 68, 54, 48]
plt.boxplot(a,vert=False,showmeans=True,notch=True,boxprops=dict(color="r"),whiskerprops=dict(color="g"))
plt.show()

# %%
x1=[60,40,55,78,77]
x2=[61,41,56,79,80,88,66]
df=[x1,x2]
plt.boxplot(df,vert=False,labels=["Python","Html"])
plt.figure(figsize=(7,3))
plt.show()

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\piyush\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sen

df=sen.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
x=[20,30,40,50]
y=["Html","Css","Java","Jquery"]

plt.figure(figsize=(7,3))

plt.title("This is Hanuman Chiranda Chart",color="r",style="italic",fontsize=20)

plt.bar(y,x,color=["y","g","y","r"],width=0.5,align="edge",alpha=0.5)
plt.xlabel("Course",color="y",style="italic",fontsize=20)
plt.ylabel("Number",color="k",style="italic",fontsize=20)

plt.savefig("Hanuman Chiranda.png",dpi=200)
plt.show()

# %%
x=[20,30,40,50]
y=["Html","Css","Java","Jquery"]

plt.figure(figsize=(7,3))

plt.title("This is Hanuman Chiranda Chart",color="r",style="italic",fontsize=20)

plt.barh(y,x,color=["y","g","y","r"],align="edge",alpha=0.5)
plt.ylabel("Course",color="y",style="italic",fontsize=20)
plt.xlabel("Number",color="k",style="italic",fontsize=20)

plt.show()

# %%
x=[20,30,40,50]
y=["Html","Css","Java","Jquery"]

plt.pie(x,labels=y,autopct="%0.1f%%")
plt.legend(loc=2)
plt.show()

# %%
x=[10,20,30,40]

# %%
y=[5,6,7,8]

# %%
plt.boxplot(x,y,patch_artist=True,showmeans=True,vert=False)

plt.show()
