# %%
import matplotlib.pyplot as plt
x =['atul','rahul','srivastav']
y =[28,26,24]
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
x =['atul','rahul','srivastav']
y =[28,26,24]

plt.step()
